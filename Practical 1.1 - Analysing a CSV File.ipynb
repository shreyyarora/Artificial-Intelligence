# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('/content/drive/My Drive/CSV FILES/research-and-development-survey-2019-csv.csv', encoding= 'unicode_escape')
print(df)
# Out:
#                                           Table  ...        Unit
# 0                      01 Total R&D Expenditure  ...  $(million)
# 1                      01 Total R&D Expenditure  ...  $(million)
# 2                      01 Total R&D Expenditure  ...  $(million)
# 3                      01 Total R&D Expenditure  ...  $(million)
# 4                      01 Total R&D Expenditure  ...  $(million)
# ..                                          ...  ...         ...
# 895  15 Broad purpose of research by sub-sector  ...  $(million)
# 896  15 Broad purpose of research by sub-sector  ...  $(million)
# 897  15 Broad purpose of research by sub-sector  ...  $(million)
# 898  15 Broad purpose of research by sub-sector  ...  $(million)
# 899  15 Broad purpose of research by sub-sector  ...  $(million)
#
# [900 rows x 6 columns]

# %%
print(list(df))
# Out:
# ['Table', 'Breakdown', 'Secondary_Breakdown', 'Year', 'Value', 'Unit']

# %%
print(df.dtypes)
# Out:
# Table                  object
# Breakdown              object
# Secondary_Breakdown    object
# Year                    int64
# Value                  object
# Unit                   object
# dtype: object

# %%
md=df.head(50)

# %%
import matplotlib.pyplot as plt
a=md["Value"]
b=md["Secondary_Breakdown"]
x=list(a)
y=list(b)

plt.bar(x,y)
# Out:
# <BarContainer object of 50 artists>
