# %%
from google.colab import drive
path="/content/drive/My Drive/FL1.txt"

# %%
with open(path,"r") as file1:
  content=file1.read()
  print(content)
# Out:
# Hello, my name is Shrey Arora.
# I am a student of UPES, Dehradun.
# I am curently pursuing B.tech in Computer Science with specialization in Open Source and Open Standards.

# %%
with open(path,"a") as file2:
  file2.write("\nI am 20 years old\n")
  file2.write("I love sleeping")

# %%
with open(path,"r") as file1:
  content=file1.read()
  print(content)
# Out:
# Hello, my name is Shrey Arora.
# I am a student of UPES, Dehradun.
# I am curently pursuing B.tech in Computer Science with specialization in Open Source and Open Standards.
# I am 20 years old
# I love sleeping
